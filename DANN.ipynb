# %%
# Use wget to download the file
# !wget -O dataset.zip "https://drive.usercontent.google.com/download?id=0B81rNlvomiwed0V1YUxQdC1uOTg&export=download&authuser=0&resourcekey=0-2SNWq0CDAuWOBRRBL7ZZsw&confirm=t&uuid=20d36250-c361-43f0-af89-b54c8b82e050&at=ALoNOgnxSkuLroiv4Hfubihzg2a9%3A1748447835648"

# Optional: Unzip if it's a zip file
# !unzip -q dataset.zip
# Out:
# --2025-06-01 20:48:12--  https://drive.usercontent.google.com/download?id=0B81rNlvomiwed0V1YUxQdC1uOTg&export=download&authuser=0&resourcekey=0-2SNWq0CDAuWOBRRBL7ZZsw&confirm=t&uuid=20d36250-c361-43f0-af89-b54c8b82e050&at=ALoNOgnxSkuLroiv4Hfubihzg2a9%3A1748447835648
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.2.132, 2607:f8b0:4023:c0d::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1132166928 (1.1G) [application/octet-stream]
# Saving to: ‘dataset.zip’
#
# dataset.zip         100%[===================>]   1.05G   125MB/s    in 10s
#
# 2025-06-01 20:48:24 (108 MB/s) - ‘dataset.zip’ saved [1132166928/1132166928]

# %%
# !unzip DANN_py3.zip
# Out:
# Archive:  DANN_py3.zip
#    creating: DANN_py3/
#   inflating: DANN_py3/functions.py
#   inflating: __MACOSX/DANN_py3/._functions.py
#   inflating: DANN_py3/.DS_Store
#   inflating: __MACOSX/DANN_py3/._.DS_Store
#   inflating: DANN_py3/LICENSE
#   inflating: DANN_py3/Dockerfile
#    creating: DANN_py3/dataset/
#   inflating: DANN_py3/data_loader.py
#   inflating: __MACOSX/DANN_py3/._data_loader.py
#    creating: DANN_py3/models/
#   inflating: DANN_py3/test.py
#   inflating: __MACOSX/DANN_py3/._test.py
#   inflating: DANN_py3/model.py
#   inflating: __MACOSX/DANN_py3/._model.py
#   inflating: DANN_py3/README.md
#   inflating: DANN_py3/.gitignore
#    creating: DANN_py3/.git/
#   inflating: DANN_py3/main.py
#   inflating: __MACOSX/DANN_py3/._main.py
#    creating: DANN_py3/dataset/mnist_m/
#  extracting: DANN_py3/models/.gitkeep
#   inflating: DANN_py3/.git/config
#    creating: DANN_py3/.git/objects/
#   inflating: DANN_py3/.git/HEAD
#    creating: DANN_py3/.git/info/
# ...

# %%
# !mv /content/data /content/DANN_py3

# %%
# !unzip data.zip
# Out:
# Archive:  data.zip
#    creating: data/
#   inflating: __MACOSX/._data
#    creating: data/svhn2mnist/
#   inflating: __MACOSX/data/._svhn2mnist
#   inflating: data/.DS_Store
#   inflating: __MACOSX/data/._.DS_Store
#    creating: data/image-clef/
#   inflating: __MACOSX/data/._image-clef
#    creating: data/office/
#   inflating: __MACOSX/data/._office
#    creating: data/office-home/
#   inflating: __MACOSX/data/._office-home
#    creating: data/usps2mnist/
#   inflating: __MACOSX/data/._usps2mnist
#   inflating: data/svhn2mnist/svhn2mnist_dataset.py
#   inflating: __MACOSX/data/svhn2mnist/._svhn2mnist_dataset.py
#   inflating: data/svhn2mnist/mnist_image.tar.gz
#   inflating: __MACOSX/data/svhn2mnist/._mnist_image.tar.gz
#   inflating: data/svhn2mnist/mnist_test.txt
#   inflating: __MACOSX/data/svhn2mnist/._mnist_test.txt
#   inflating: data/svhn2mnist/svhn_balanced.txt
#   inflating: __MACOSX/data/svhn2mnist/._svhn_balanced.txt
#   inflating: data/svhn2mnist/mnist_train.txt
# ...

# %%
# !mv /content/OfficeHomeDataset_10072016/Art /content/OfficeHomeDataset_10072016/Clipart/ /content/OfficeHomeDataset_10072016/Product/ /content/OfficeHomeDataset_10072016/Real\ World /content/DANN_py3/data/office-home/images

# %%
# %cd DANN_py3/
# Out:
# /content/DANN_py3

# %%
# !python main_with_pgd.py --output_dir my_experiment
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100% 97.8M/97.8M [00:00<00:00, 215MB/s]
# Epoch: 0, [Iter: 137 / 137], err_s_label: 2.827395, err_s_domain: 0.754502, err_t_domain: 0.635419
#
# ...
